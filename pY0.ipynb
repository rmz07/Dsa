# %% [markdown]
# <a href="https://colab.research.google.com/github/rmz07/Dsa/blob/main/pY0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hellow")
# Out:
# Hellow
